# %%
from tensorflow.python.platform import gfile
import tensorflow as tf
import data_utils_orig # our data preprocessing functions
import pandas as pd

# %%
# Load the dev data files
en_fname = "./data/dev.en"
vi_fname = "./data/dev.vi"

# create vocabulary
data_utils_orig.create_vocabulary("./data/dev_vocab.en","./data/dev.en",100)
data_utils_orig.create_vocabulary("./data/dev_vocab.vi","./data/dev.vi",100)

# get vocab pairs
en_vocab_pairs = data_utils_orig.initialize_vocabulary("./data/dev_vocab.en")
vi_vocam_pairs = data_utils_orig.initialize_vocabulary("./data/dev_vocab.en")

# sentence to token ids
token_ids = sentence_to_token_ids(sentence, vocabulary,tokenizer=None, normalize_digits=True)

# %%
fname1 = "./data/dev_vocab.en"
fname2 = "./data/dev_vocab.vi"

with open(fname1) as f1:
    content1 = f1.readlines()

# %%
with open(fname1) as f:
   for line in f:
       print line
       if 'str' in line:
          break
# Out:
# _PAD
#
# _GO
#
# _EOS
#
# _UNK
#
# ,
#
# .
#
# the
#
# ;
#
# of
#
# to
#
# a
#
# and
#
# &apos
#
# in
#
# that
#
# &quot
#
# we
#
# is
#
# s
#
# you
#
# And
#
# it
#
# as
#
# on
#
# have
#
# they
#
# We
#
# with
#
# brain
#
# this
#
# their
#
# was
#
# can
#
# --
#
# what
#
# do
#
# I
#
# one
#
# are
#
# 00
#
# film
#
# look
#
# all
#
# for
#
# or
#
# an
#
# our
#
# ?
#
# It
#
# young
#
# 000
#
# pain
#
# from
#
# re
#
# like
#
# be
#
# into
#
# at
#
# The
#
# his
#
# But
#
# In
#
# by
#
# my
#
# how
#
# not
#
# there
#
# who
#
# these
#
# You
#
# people
#
# your
#
# &amp
#
# could
#
# which
#
# see
#
# had
#
# human
#
# world
#
# her
#
# films
#
# control
#
# years
#
# were
#
# he
#
# ve
#
# has
#
# real
#
# about
#
# but
#
# inside
#
# up
#
# They
#
# when
#
# narrative
#
# time
#
# me
#
# never
#
# experience
#
# fly
