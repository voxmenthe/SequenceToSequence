# %%
import os
import re

from tensorflow.python.platform import gfile
import tensorflow as tf

from DataUtils import DataUtils
from Config import Config
from attn_cell import attn_cell, _linear

# %%
x = DataUtils()

# %%
x.to_vocab_file
# Out:
# 'data/vocab.vi'

# %%
x.en_vocab_from_train
# Out:
# {'': 133314,
#  'One &apos;s a boiling chamber , and one &apos;s the water holder .': 86868,
#  'Now she &apos;s the best student , not just in our school , but in the entire division that we are in .': 105754,
#  'You can &apos;t do a thing about it .': 36085,
#  'Now the background is -- the guy who did this is a physicist .': 77927,
#  'We have a big study which we published last year on schizophrenia , and the data were quite extraordinary .': 113078,
#  'Then I said , &quot; Well fuck it , we &apos;ll just change the rules . &quot;': 42158,
#  'But I wondered , what about when it rained ?': 129768,
#  'Does this then mean that there is after all some absolute difference between people outside Africa and inside Africa in that people outside Africa have this old component in their genome from these extinct forms of humans , whereas Africans do not ?': 104116,
#  'But what they know is they know how to resurrect it .': 3892,
#  'Niall , I am just curious about your take on the other region of the world that &apos;s booming , which is Latin America .': 111432,
#  'I think that approach denies reality .': 56665,
#  'This might look familiar .': 38314,
#  'Maybe we should make people save more when they make more money .': 104279,
#  'What do we learn from that ?': 55724,
#  'She &apos;s like you , and she &apos;s like me .': 114873,
#  'And when the great big parachute opened , we knew that if it didn &apos;t open there &apos;s a second parachute , and it runs on a nice little clockwork mechanism .': 130126,
#  'In the first phase of this testing , which is called testing for toxicity , it &apos;s called Phase I.': 96195,
#  'That people have just sort of figured out about it , and now with Kyoto and the Governator and people beginning to actually do something , we may be on the road to a solution .': 61473,
#  'Now , of the women that could tell them apart , when the labels were off , they picked &quot; Adorable , &quot; and when the labels were on , they picked &quot; Ballet Slippers . &quot;': 79428,
#  'Nor did he tell us , &quot; Trust us . Trust your country .': 42481,
#  'We were experimenting with type , with illustration , with photos . And we had fun .': 75816,
#  'There &apos;s nothing we can do . &quot;': 14762,
#  'Here &apos;s the Apple marketing video .': 102130,
#  'In other words , what is a meritocratic society ?': 56101,
#  'This is a new idea that &apos;s crept up that may be , essentially , a cleverer idea than putting sulfates in .': 61579,
#  'And my time is up . And I know the TED commandments .': 46564,
#  'You can &apos;t force people of free will , and I totally support that .': 33723,
#  'This is what we must fight hard to hold like it is now .': 107220,
#  'Their religion , their isolation , their deep respect for their culture and now the principles of their GNH movement all have fostered a sense of gratitude about what they do have .': 101422,
#  'They fly into this thing , and they fly all the way down it .': 6517,
#  'And every time , we see the same thing .': 36911,
#  'But the experiment is not the end of the story , because you still have to transmit that knowledge to other people .': 72391,
#  'And when things start to change , when conditions start to deteriorate , we move into the red line .': 91467,
#  'And they &apos;d say , &quot; Play that part again . &quot;': 836,
#  'We read &apos; Huck Finn , &apos; of course , we read &apos; Huck Finn &apos; of course .': 51427,
#  'So two people who grew up in the Great Depression , there in the very , very early &apos; 80s took on a new kid .': 98580,
#  'MT : Well , maybe you shouldn &apos;t have told them it could be used to contact other planets .': 63206,
#  'The bulkheads have now turned into hoops of cane , but it &apos;s ultimately the same structure .': 30962,
#  'And it raises the question of how we &apos;re going to define animal species in the age of biotechnology -- a question that we &apos;re not really sure yet how to solve .': 4565,
#  'We do that in our personal lives .': 90930,
#  'I was always that kind of obsessed trivia kid .': 69092,
#  'I did something that nobody else had done .': 109867,
#  'And you can understand , obviously , the transmission problem between people in high-virus areas .': 91693,
#  'Here are two possible paths to that ball .': 107609,
#  'So when you finally actually get outside on a spacewalk , it feels much different than it would if you just went out first time .': 130102,
#  'And an average user , said Cameron Marlow , from Facebook , has about 120 friends .': 39904,
#  'That not only helps Europe diminish its reliance on Russia for energy , but if you travel to North Africa today , you &apos;ll hear more and more people saying that they don &apos;t really think of their region as the Middle East .': 64528,
#  'I &apos;m lying in the tent , getting ready to go .': 119232,
#  'What I wanted to show you is that scientists , using their from-the-outside , third-person methods , can tell you things about your own consciousness that you would never dream of , and that , in fact , you &apos;re not the authority on your own consciousness that you think you are .': 15522,
#  'The synchrony of emotions that we experience when we hear an opera by Wagner , or a symphony by Brahms , or chamber music by Beethoven , compels us to remember our shared , common humanity , the deeply communal connected consciousness , the empathic consciousness that neuropsychiatrist Iain McGilchrist says is hard-wired into our brain &apos;s right hemisphere .': 115635,
#  'Interestingly , Madeira first got the insect in 2005 , and here we are , a few years later , first cases of dengue .': 88405,
#  'And so deep down our nature &apos;s actually nasty .': 108717,
#  '37 squared , OK .': 78860,
#  'The list goes on , and it will grow fast , because industrial data are now growing exponentially .': 73532,
#  'and I &apos;m probably like , &quot; The legs get worked out . &quot;': 98913,
#  'And I thank god I didn &apos;t know just how huge this man is in the track and field world .': 83214,
#  'And these micro-machines power how a cell moves .': 85997,
#  'Cities are fundamentally about people , and where people go and where people meet are at the core of what makes a city work .': 128888,
#  'Let &apos;s start with the global challenge of urbanization .': 122066,
#  'I &apos;m not talking about designing telephones that look like that , and I &apos;m not looking at designing architecture like that .': 49902,
#  'And one more thing : Archie was suffering from this illness himself .': 98366,
#  'And I think the key to that is self-assembly .': 86682,
#  'And this open-heartedness is exactly what I &apos;ve experienced in the entire organization of this gathering since I got here yesterday .': 80228,
#  'If you divide the amount of water into what the farmer was paid , the farmer didn &apos;t receive enough money to pay a decent price for water in any of those commodities .': 93666,
#  'So here &apos;s to another day at the office .': 52902,
#  'There are these giant rocks flying out there , and they &apos;re hitting us , and they &apos;re doing damage to us , but we &apos;ve figured out how to do this , and all the pieces are in place to do this .': 113713,
#  'Which brings us to bats .': 131216,
#  'By the time the pilot had finished , we had the names of a thousand schools that wished to join .': 127,
#  'And I think as that happens , it &apos;s going to become possible for our digital personas to continue to interact in the real world long after we &apos;re gone thanks to the vastness of the amount of content we &apos;re creating and technology &apos;s ability to make sense of it all .': 33685,
#  'So at the top you have a socket , and this fits over someone &apos;s residual limb , and everyone &apos;s residual limb is a little bit different .': 92243,
#  'But smallpox eradication was hard ; it was very , very hard .': 1569,
#  'It &apos;s you talking to yourself . What do you do before you go into a job interview ? You do this .': 66722,
#  'And that &apos;s what this theory taught me about my field .': 91006,
#  'And then the other thing about this project is , we bring intellectual property , we bring a marketing approach , we bring all this stuff , but I think , at the end of the day , what we bring is these values , and these values create a soul for the companies we work with .': 4423,
#  'And the results were so good that the Rwandan government has now agreed to adopt the model for the entire country , and has strongly supported and put the full resources of the government behind it .': 54443,
#  'But you see , when you &apos;re using a computer , you can just substitute .': 36777,
#  'Anonymous companies might be the norm right now but it wasn &apos;t always this way .': 129981,
#  'There were pigeons roosting in the dish .': 28135,
#  'With 10 million solutions .': 85924,
#  'George : On that day , at around 6 : 30 I was driving with my wife and daughters to the supermarket .': 33846,
#  'I want to change pace to one last little demonstration , a technique that is wonderfully simple and basic , but is interesting in exposing how much information we &apos;re all giving away , and it &apos;s relevant because it applies to us as a TED audience .': 63074,
#  'It &apos;s more like that .': 100064,
#  'Older people who keep learning and are curious , they have much better health outcomes than those who start to close down .': 18923,
#  'The Netherlands is on the left . And Belgium is on the right .': 112104,
#  'While they &apos;re taking the podium away , just a quick question .': 36030,
#  'I don &apos;t think it does . I think it &apos;s already part of a Euro-Turkish superpower .': 64534,
#  'But India still has a lot of work to do in terms of gender equality .': 35612,
#  'If you watch the news , you &apos;ll see occasionally -- and I see this all the time -- that pharmacists now , there &apos;s a machine that can fill prescriptions automatically without actually needing a human pharmacist .': 69161,
#  'I would like to think that he &apos;s a good boy , a respectful young man . I would like to think that I &apos;ve proven to be a capable father .': 113846,
#  'And then here &apos;s Senegal \xe2\x80\x94 it &apos;s got a higher level of social progress than Chad , but the same level of GDP .': 121833,
#  'Not a lot .': 81516,
#  'Jill Bolte Taylor got a research opportunity few brain scientists would wish for : She had a massive stroke , and watched as her brain functions -- motion , speech , self-awareness -- shut down one by one . An astonishing story .': 82865,
#  'And a few people got excited about it .': 112533,
#  'Tempered with love , of course , honesty is a great thing .': 125829,
#  'And I put it to you , that is not business as usual .': 18878,
#  'Nobody believed us . Nobody wanted to work with us .': 119878,
#  'And then for the damaged arthritis on the surface , we did a stem cell paste graft , which we designed in 1991 , to regrow that articular cartilage surface and give it back a smooth surface there .': 4999,
#  'But did the regime learn anything ? Not really .': 38904,
#  'Space may be finite or infinite , but because the universe is accelerating , there are parts of it we cannot see and never will see .': 76990,
#  'The Chinese government blocked every single international Web 2.0 service , and we Chinese copycat every one .': 109591,
#  'I made a paper tube shelter for them , and in order to make it easy to be built by students and also easy to demolish , I used beer crates as a foundation .': 5362,
#  'And I tell people that this is where great stories start from -- these four intersections of what you &apos;re passionate about and what others might be invested in .': 66175,
#  'A lot of people buy the biggest house they can afford , and actually slightly bigger than that .': 104136,
#  'It &apos;s the only swim I &apos;m interested in .': 29910,
#  'It &apos;s used in paint for the texture , but also for the glossiness .': 81391,
#  'Here , we &apos;ve got a protocell to extract carbon dioxide out of the atmosphere and turn it into carbonate .': 96845,
#  'And so , for the first time , I am showing this .': 109857,
#  '&quot; It was awesome .': 57262,
#  'We actually take a very small piece of the bladder from the patient -- less than half the size of a postage stamp .': 22665,
#  'I think back to my father .': 1839,
#  'So , an optimal diet is low in fat , low in the bad carbs , high in the good carbs and enough of the good fats .': 39081,
#  'What had changed to make a new name necessary precisely at that moment ?': 13626,
#  'Within just five years , we had multiplied that 554 times into 194 million dollars after all expenses for breast cancer research .': 62079,
#  'This is the archetype of the hard disk that &apos;s in your machine now .': 20473,
#  'So , for example , we could say , well what is it that the brain does ?': 132803,
#  'They &apos;re referred to as nuclear batteries .': 104741,
#  '50 percent of the population over the age of 40 suffers from diabetes .': 110859,
#  'This is separate from vitamin D.': 71116,
#  'And they pasted &#91; over &#93; every single portrait of the dictator &#91; with &#93; their own photos .': 80054,
#  'And it &apos;s very important to have political reforms , to have widely shared benefits of economic growth .': 35661,
#  'The humble potato -- and I &apos;ve spent a long time , 25 years , preparing these .': 110633,
#  'This is the result of computational geometry , gesture recognition , and machine learning .': 17775,
#  'The other option we could choose was to develop the systems of communication that would allow us to share ideas and to cooperate amongst others .': 34870,
#  'So what you see here -- I know it sounds funny , but that &apos;s the way it works .': 22691,
#  'This meant they must have been closer together in the past .': 2211,
#  'And I &apos;m really pleased to report to you today that the first synthetic self-cleaning , dry adhesive has been made .': 43047,
#  'They live around things , and so their spatial awareness relationship , and their thinking around storage is totally different .': 95703,
#  'Or if they get an extra ration of food at the end of the week -- it costs about 50 cents -- will keep a girl in school , and they &apos;ll give birth to a healthier child , because the malnutrition is sent generation to generation .': 97925,
#  'If it was very low , one would have expected it to take most of the ten billion years available .': 2238,
#  'We did Haemophilus influenzae and then the smallest genome of a self-replicating organism , that of Mycoplasma genitalium .': 113121,
#  'Global warming fun .': 71476,
#  'In fact , the Chinese had their own version of broccoli , which is called Chinese broccoli , but right now , what -- they &apos;ve now discovered American broccoli , and are importing it as a , sort of , exotic delicacy .': 10993,
#  'There &apos;s a lot going on there .': 11277,
#  'His father wasn &apos;t on the set .': 1866,
#  'Once we realized that , we decided it was time to do our own planning .': 8769,
#  'You hear about people with Google Glass being attacked .': 122305,
#  'Audience : 1949 . 1949 , and the month ?': 78965,
#  'And that &apos;s what I do with my furniture .': 50017,
#  'And it stays with the idea that I am this body , I am this physical organism .': 57898,
#  'And once again , a mystery wrapped inside of a mystery -- perhaps the key to Derartu Tulu and the Tarahumara is wrapped in three other mysteries , which go like this : three things -- if you have the answer , come up and take the microphone , because nobody else knows the answer .': 44072,
#  'That &apos;s what we try to do in different places .': 22070,
#  'Half as much money was spent on this Norden bombsight as was spent on the most famous military-industrial project of the modern era .': 81480,
#  'So it immediately cools , and it can no longer hold in suspension all of the material that it &apos;s dissolved , and it precipitates out , forming black smoke .': 92635,
#  'That flower doesn &apos;t come in bright orange , I don &apos;t think .': 107921,
#  'Perhaps we feel that many of our relationships have not had closure .': 60268,
#  'Kepler was asking the wrong question .': 18008,
#  'And when they went back out in the field , his men brought him some of their food so that he may eat , We call them leaders because they go first .': 127149,
#  'So they vibrate the flower , they sonicate it , and that releases the pollen in this efficient swoosh , and the pollen gathers all over the fuzzy bee &apos;s body , and she takes it home as food .': 60388,
#  'Or perhaps I should say , more accurately , Se\xc3\xb1or Pringle .': 89898,
#  'Wassup .': 31486,
#  'They don &apos;t have time to relax .': 54924,
#  'Also in 1871 , we ended the time of treaty-making .': 110796,
#  'UE : Thank you very much .': 10212,
#  'But the story is not about these chapters .': 132460,
#  'But this complement may be much inferior to what , with other laws and institutions , the nature of its soil , climate , and situation might admit of . &quot;': 111324,
#  'I started paying closer attention to women &apos;s lives in Gaza .': 123381,
#  'Nowadays there are hundreds of links to choose from .': 16994,
#  'What &apos;s important for today &apos;s talk is that we know that there are hundreds of behaviors that bacteria carry out in these collective fashions .': 23841,
#  'I was a big record collector -- the records didn &apos;t make it . Boy , I tell you , film burns . Film burns .': 77738,
#  'And that &apos;s something that &apos;s easy to forget .': 46170,
#  'My children are Americans .': 123012,
#  'You do find groups in the animal kingdom -- you do find cooperative groups -- but these groups are always either very small or they &apos;re all siblings .': 70128,
#  'That empty space lasts essentially forever .': 77056,
#  'I want to talk to you about something kind of big .': 113588,
#  'I was a guest student during one month of a public health course .': 22293,
#  'I did this again last October .': 127302,
#  'Well , I &apos;m going to kill a few , but there won &apos;t be any genocide .': 42897,
#  'In this case , it was picking up bones and creating a tool , using it as a tool , which meant that apes just , sort of , running around and eating and doing each other figured out they can make things if they used a tool .': 116616,
#  'I could not have designed that in teaching it .': 18685,
#  'Because , after all , within living memory , they were hunters and gatherers , living pretty much like our ancestors lived for maybe 99 percent of the human story .': 24592,
#  'When the turbine drops in , it will produce 8,000 watts of electricity , day and night .': 53425,
#  'It &apos;s riddled with gimmicks . &quot;': 112747,
#  'Now , ironically , what happened was it was eliminated from all the temperate zones , which is where the rich countries are .': 21560,
#  'And this is so important in breaking through the stigma .': 12721,
#  'And then let &apos;s think how compassion informs wisdom , and that vulnerability is our greatest strength , and that emotions have inherent logic , which lead to radical , appropriate , saving action .': 20131,
#  'Almost every field of science engineering and clinical practice is involved in trying to get this to happen .': 17581,
#  'I thought about it , and when I was four , I was already the oldest of four children , and my mother even had another child to come , so what I think she understandably really meant was that she was so ready , she was so ready . Then she said , &quot; Don &apos;t worry , Julie , every year on October 10 when it was your birthday but you didn &apos;t realize it , I made sure that you ate a piece of cake that day . &quot;': 113272,
#  'You didn &apos;t even need to be a billionaire to get on that list in 1992 .': 63339,
#  'So the message he was giving us was you must get more from less and less and less so that you can share it for more and more people , not only the current generation , but the future generations .': 39295,
#  'Now you can probably make it , but it &apos;s going to be a pretty flimsy apparatus I think .': 108754,
#  'There &apos;s a revolution going on .': 43576,
#  'But careful now -- we are approaching the First World War .': 22353,
#  'Okay ? It used to be seven , but with functional MRIs , apparently it &apos;s four , and we were overachieving .': 70008,
#  'In 1979 , I witnessed my first military coup .': 85292,
#  'We became bald-bodied , oddly enough ; for one reason or another , they didn &apos;t .': 61697,
#  'So I set up a scientific criteria as to what a sensor would have to look like in order to effectively diagnose pancreatic cancer .': 44705,
#  'They &apos;re looking for answers to questions , and they want to take action when they &apos;re done , which is really hard to do from a site that looks like this .': 7429,
#  'Calculating this at the national level is one thing , and it has begun .': 74046,
#  'I want you to consider the following chart , of systolic blood pressure measurements from October 2010 to July 2012 .': 125105,
#  'I &apos;ve had to do away with a few concepts of design past .': 104476,
#  'I believe it was -- one great philosopher said -- no , no , Cervantes . Cervantes said , &quot; The journey is better than the end . &quot;': 92046,
#  'I &apos;d like to talk about what I call digital food .': 97946,
#  'But what if a country can &apos;t afford to pay more because it &apos;s maybe too expensive ?': 103806,
#  'And we &apos;re always below the glass ceiling , the women .': 46341,
#  'You can use statistics , or you can use stories .': 109504,
#  'Using the oxytocin inhaler , we ran more studies .': 106018,
#  'First thing to notice is , half of them do not even have access to a 401 plan .': 104172,
#  'So that &apos;s one point for insects .': 5142,
#  'So , this is not something pretty and nice to do .': 91170,
#  'It &apos;s a way of processing what &apos;s going on so that we can use it later .': 70030,
#  'More money , less drugs . Hmm .': 77759,
#  'In this vein , we can increase economic growth .': 132427,
#  'These are in Hong Kong ; we have nothing like that here .': 108466,
#  'All of the animals are gone , they &apos;re dead , and the chimneys are still there creating a really nice ghost town , an eerie , spooky ghost town , but essentially devoid of animals , of course .': 92650,
#  'As you know , a lot of organs are actually discarded , not used .': 22674,
#  'And I &apos;m actually going to use his words in the same order that he did .': 47114,
#  'We &apos;ve all seen the photos of the collapsed buildings in Haiti .': 117363,
#  'And indeed this is actually true for most scientists as well outside of their own specialties .': 126025,
#  'And so this would be the typical talk I would give .': 34574,
#  'I mean , this is a true story . They &apos;re using policemen as canaries .': 13825,
#  'So I &apos;m committing to potatoes ; I &apos;m committing to milk ; I &apos;m committing to leeks and broccoli -- all very important stuff .': 110730,
#  'So makers are enthusiasts ; they &apos;re amateurs ; they &apos;re people who love doing what they do .': 77901,
#  'For example , this is , of course , one of the most delicious tricks in marketing , is to say something used to be higher , and suddenly it seems like a very good deal .': 33157,
#  'So we have to manage many claims to the same video .': 92472,
#  'The first story that I did for National Geographic , where I recognized the ability to include environmental issues within a natural history coverage , was a story I proposed on harp seals .': 77503,
#  'The second reason is that we killed these things .': 24228,
#  'And I realized that if I was going to ask my students to speak up , I was going to have to tell my truth and be honest with them about the times where I failed to do so .': 124801,
#  'These are quartz crystals and feldspar , so most sand in the world on the mainland is made of quartz crystal and feldspar . It &apos;s the erosion of granite rock .': 14843,
#  'In addition to that , it &apos;s listed , the artist &apos;s name , the location , how long they spent drawing it .': 51766,
#  'But as we &apos;ve seen over the last year , I think that &apos;s an idea that is increasingly coming into question .': 12176,
#  'And then , you might have heard of this giant clam that was discovered off the coast of northern Iceland that reached 405 years old .': 81130,
#  'Can farm-raised salmon be organic , when its feed has nothing to do with its natural diet , even if the feed itself is supposedly organic , and the fish themselves are packed tightly in pens , swimming in their own filth ?': 8537,
#  'What about copying , reusing , right ?': 23983,
#  'We keep our office almost like an archive of architectural biodiversity .': 58960,
#  'The point is that we have to have a context , a gauge for our actions in all this .': 93793,
#  'So this is Doug Engelbart .': 108650,
#  'And I was just struck that this is out of place .': 97864,
#  'To be a leader means not to be a girl .': 20139,
#  'Of course we should .': 4829,
#  'And he says , &quot; I &apos;ve got something else , but it may not be for you . &quot;': 21087,
#  'There &apos;s no conversation .': 90912,
#  'The truth is sub-Saharan Africa has 24 percent of the global disease burden and yet only three percent of the world &apos;s health care workers .': 12652,
#  'Most people say , &quot; I &apos;d like to die at home . &quot;': 94889,
#  'His grandmother had two jobs .': 1867,
#  'God himself was utterly familiar from his earlier manifestation as Yahweh -- jealously insisting on no other gods .': 31542,
#  'Obviously the whole project here is huge .': 106177,
#  'This is good information to have , and it &apos;s not that complicated .': 12834,
#  'We feel good if we give .': 18930,
#  'Now that &apos;s a lot of money .': 89979,
#  'And we have global celebrations , and we &apos;ve actually started to -- you know , we &apos;ve seen the worst of it .': 61625,
#  'Because they help people share news .': 84623,
#  'Then we set out to create an open source , DIY , do it yourself version that anyone can build and maintain at a fraction of the cost .': 94024,
#  'It is the central psychological plague of humankind in the 21st century .': 54366,
#  'You &apos;ve seen the documentaries of sweatshops making garments all over the world , even in developed countries .': 119011,
#  'I &apos;m going to echo his words : &quot; I , for one , welcome our new computer overlords . &quot;': 99016,
#  'Designers want to respond to issues of humanitarian crisis , but they don &apos;t want some company in the West taking their idea and basically profiting from it .': 85937,
#  'And one young Ranger in the back -- his hair &apos;s tousled and his face is red and windblown from being in combat in the cold Afghan wind -- he said , &quot; Sir , I was in the sixth grade . &quot;': 2049,
#  'They &apos;re really difficult for plants to produce .': 6446,
#  'They have in-built bidet nozzles for a lovely , hands-free cleaning experience , and they have various other features like a heated seat and an automatic lid-raising device which is known as the &quot; marriage-saver . &quot;': 13961,
#  'Because if compassion was a chore , nobody &apos;s going to do it , except maybe the Dalai Lama or something .': 54514,
#  'It &apos;s not fair to students , and it &apos;s putting America &apos;s global leadership at risk .': 37938,
#  'And some people are blind because they think , well , seeing anything is just futile .': 114839,
#  'Divide that by the number of minutes in a year , and you wind up with three new papers per minute .': 132742,
#  'And so what I love about this story is that Rosey Grier is just such an authentic person , and that &apos;s what authenticity is all about .': 78277,
#  'What &apos;s your evidence that this could be feasible ? &quot;': 91276,
#  '&quot; You can exchange groups .': 114518,
#  'Sugata Mitra : The child-driven education': 114413,
#  'And I took out a centrifuge and dry ice and needles and tubes .': 106107,
#  'AIDS was discovered 1981 ; the virus , 1983 .': 42690,
#  'But you &apos;ll notice we &apos;re not at the top of the mountain yet .': 6316,
#  'This is where meerkats live .': 131250,
#  'We went back to Afghanistan , because the next year was coming , and we wanted to support .': 7735,
#  'They also have a 3,000-year-old adage , which I think is the greatest sort of diet suggestion ever invented .': 82342,
#  'I flew in one night and took this picture .': 14147,
#  'The Sardinians pray . The Seventh-Day Adventists pray .': 82437,
#  'So this leads to a new role for the architect .': 4033,
#  'And it could be larger than that .': 28751,
#  'And they stay high regardless of the political innovations .': 56670,
#  'The teenagers said they could see very well .': 106392,
#  'So all this vast amount of information is then fed into the computer , and the computer can do two things .': 84050,
#  'I didn &apos;t realize that it would become the most amazing journey of my life .': 67087,
#  'It &apos;s more curiosity .': 18925,
#  'But , we also must admit that we haven &apos;t been good at using those same networks and technologies to successfully articulate an alternative to what we &apos;re seeing and find the consensus and build the alliances that are needed to make it happen .': 123054,
#  'And to understand that , you have to understand a little bit about how stealth works .': 93121,
#  'AM : Well , for those of you who have seen the picture in the little bio -- it might have given it away -- I &apos;m a double amputee , and I was born without fibulas in both legs .': 83187,
#  'This happens about the same time that they get latched onto things like dinosaurs , these big things in the outside world that they &apos;re trying to get a grip on .': 80303,
#  'If you look at birds , which live a long time , cells from the birds tend to be more resistant to a lot of different environmental stresses like high temperature or hydrogen peroxide , things like that .': 100054,
#  'And in fact , through those interactions , for the first time , I was starting to get to be friends with some of those people in that big amorphous group out there that was supposed to be far away .': 96350,
#  'Back to the DFS . A huge chemical depot caught fire , thousands of drums filled with petrochemicals were blazing away and exploding all around us .': 46877,
#  'Another direct result was a young grad student named Ben Novak , who had been obsessed with passenger pigeons since he was 14 and had also learned how to work with ancient DNA , himself sequenced the passenger pigeon , using money from his family and friends .': 28213,
#  'This is underneath my alma mater , Columbia University .': 66323,
#  'Traditional imaging satellites use a line scanner , similar to a Xerox machine , and as they traverse the Earth , they take pictures , scanning row by row by row to build the complete image .': 104662,
#  'We were not playing in L.A. on the regular &quot; Jeopardy &quot; set .': 69136,
#  'Then everyone was given 45 minutes of work that would directly lead them towards their goal , but they were told that they could stop at any time .': 49245,
#  'Conversely , in sports where diminutive stature is an advantage , the small athletes got smaller .': 127890,
#  'It &apos;s actually in the key of B flat .': 113904,
#  'It &apos;s got , by now , pretty good coverage of everything you might find in a standard reference library .': 49543,
#  'Worldwide incomes have grown at a faster rate in the past decade than ever in history .': 79082,
#  'I didn &apos;t have patience for my body ; I snapped it into shape .': 116465,
#  'So you &apos;ve got a lot of information . That &apos;s great .': 109949,
#  'No special needs schools .': 29070,
#  'We have a visceral reaction to the idea that anyone would make very much money helping other people .': 62004,
#  'That doesn &apos;t mean that there &apos;s cancer inside .': 84218,
#  'In fact , we &apos;re more closely related to fungi than we are to any other kingdom .': 109745,
#  'She could come to work in her pajamas and nobody would care .': 27642,
#  'He played an important role in the Taiping rebellion , which was a war started by a guy who thought he was the son of God and the baby brother of Jesus Christ .': 11006,
#  'You know , from a romance language .': 34221,
#  'So what we &apos;re saying , essentially , is maybe that &apos;s a habitat for life in the solar system .': 15778,
#  'We can ask , &quot; Where is it inside , if we stimulate it with a picture ? &quot;': 95421,
#  'Similarly , a study in e-content showed that much of global news from U.S. news creators is recycled stories from the AP wire services and Reuters , and don &apos;t put things into a context that people can understand their connection to it .': 65265,
#  'Chris Jordan : Turning powerful stats into art': 34962,
#  'Now , all of these things are acquired tastes , but they form almost a badge of identity .': 127369,
#  'So can we have the lights off , please , so we can see it ?': 31884,
#  'It &apos;s essentially a fundamental shift in our relationship with stuff , with the things in our lives .': 99091,
#  'So all you do is -- it &apos;s a very kind of provocative statement -- this old bicycle tube and this old plastic &#91; unclear &#93; This filling cap will go very snugly into an old bicycle tube .': 44550,
#  'So we raised this 45,000-pound steel ring .': 60607,
#  'I learned that she did not have to be abused because she is a woman .': 105722,
#  'What &apos;d he say ? He said what surgeons always say : &quot; We got it all . &quot;': 2296,
#  'And they found that 100 percent of the children that had not eaten the marshmallow were successful .': 47063,
#  'I still have -- or did I use the word still ? I didn &apos;t mean that .': 23679,
#  'And I came back to measure what we technically call the half-lifetime of Coke -- how long does it last in the refrigerators ?': 562,
#  'Not only do our children cope very well , but they excel in it .': 48496,
#  'J Yep . Yeah , and trusted people .': 103337,
#  'He turned beet red , and he wouldn &apos;t even look at me .': 57268,
#  'So here is the real life in black .': 126129,
#  'About a year later , I get to feel that way again when we find a bag full of stuffed animals in the trash , and suddenly I have more toys than I &apos;ve ever had in my whole life .': 116585,
#  'We see that the nature of this phenomenon guarantees that they will .': 112020,
#  'Each time I get a wall in New York , I use his photos to continue spreading the project .': 80070,
#  'So your sad stories , by some chance your story will be picked up by reporters , professors or celebrities .': 109655,
#  'St. Luke &apos;s Medical Center in Houston , Texas , which has deployed industrial Internet technology to electronically monitor and connect patients , staff and medical equipment , has reduced bed turnaround times by nearly one hour .': 73521,
#  'I didn &apos;t heed it ; no , I organized it and I directed it .': 116464,
#  'But to conclude , if you want to see the Mermaid from May to December next year , don &apos;t come to Copenhagen , because she &apos;s going to be in Shanghai .': 59039,
#  'We also believe this cancer might be very old .': 21186,
#  'They said it was lousy , and it was .': 36533,
#  'This is a key issue .': 35518,
#  'While they &apos;re mating , the male is busy giving the female not just his sperm but also a nutrient-filled package called a nuptial gift .': 125741,
#  'For example , in Cambodia , it was that &#91; inaudible name &#93; did not go alone but she had 24 lawyers with her who stood up together . And in the same way , in China , they always tell me , &quot; It &apos;s like a fresh wind in the desert when we can come together . &quot;': 31628,
#  'Two years ago , we were approached by a partner of ours to digitally preserve an important heritage site , a UNESCO heritage site in Uganda , the Royal Kasubi Tombs .': 66430,
#  'And so I said , &quot; Here &apos;s the thing , I &apos;m struggling . &quot;': 90853,
#  'Growing a mushroom is also part of a larger practice of cultivating decomposing organisms called decompiculture , a concept that was developed by an entomologist , Timothy Myles .': 18443,
#  'And that this would operate as a kind of citizen observation -- that citizens would not be there just to cast individual votes , but also to help ensure the sanctity of the vote overall .': 104939,
#  'I had two undergraduate students at California Institute of Technology that worked with me .': 43402,
#  'Why don &apos;t we all team up ? Why don &apos;t we bring truce to life ?': 7763,
#  'I think the WorldWide Telescope will convince you that we may be tiny , but we are truly , wonderfully significant .': 113381,
#  'Ludwick Marishane : A bath without water': 25665,
#  'So , I implemented this pen that can help designers and architects not only think in three dimensions , but they can actually draw so that it &apos;s more intuitive to use that way .': 4873,
#  'Well , the answer came from David Ricardo in 1817 .': 27938,
#  'And while I walk outside , I &apos;ll just mention that here we &apos;re using this for telepresence , but you can equally well use this on the spot , for augmented reality .': 116091,
#  'It is the most frightening and panicky feeling that you can have .': 3235,
#  'I mean , architects have been thinking about these ideas for a long time . What we need to do now , develop things that can scale to those 300 million Chinese people that would like to live in the city , and very comfortably .': 63929,
#  'We see the bad stories on CNN and Fox and all that , but we don &apos;t see the good stories .': 85880,
#  'But they had a good question .': 41444,
#  'He &apos;s still dreaming about it .': 101779,
#  'I mean who can argue with that ?': 96323,
#  'And my husband -- this is my husband , who is very hot -- he won an award for being hot -- -- he told me , &quot; You cannot buy a banjo .': 38179,
#  'Same concept , but looking at communication dynamics in a very different sphere .': 91831,
#  'And everything we learn after that is building up towards one subject .': 49445,
#  'Because in other places , you can have interruptions , like , you can have the TV , or you could go for a walk , or there &apos;s a fridge downstairs , or you &apos;ve got your own couch , or whatever you want to do .': 30632,
#  'Just this last month it was deployed by Al Jazeera in Gaza .': 109933,
#  'Almost 85,000 people watched that video , and then they started emailing us from all over the country , asking us to come to their towns and help them to show their faces .': 24984,
#  'So I got out of school , I got a job , I got a paycheck , I got myself to the art store , and I just went nuts buying supplies .': 26974,
#  'This was eight years ago , some people were more Republican back then .': 14498,
#  'And I wanted to give them an escape .': 70722,
#  'Like I said earlier , the idea of discovering in this busy world we live in kind of seems like something you can only do with space travel now , but that &apos;s not true .': 86146,
#  'Yet , that vaccine is not available in large numbers because it &apos;s too expensive .': 80474,
#  'In these rooms , the air tracked the outdoor air relatively well , and when Charlie saw this , he got really excited .': 76690,
#  'I &apos;d like to now switch to talk about another key shortcoming of today &apos;s vaccines , and that is the need to maintain the cold chain .': 80451,
#  'It can be real time or it can be the time within the game , as is in Animal Crossing , where seasons follow each other at their own pace .': 104448,
#  'This is how you hold the needle .': 102835,
#  'It works against the left and the right , and that , you might say , is good news .': 14707,
#  'Last May I had this extraordinary 24-hour period where I saw two visions of the world living side-by-side -- one based on violence and the other on transcendence .': 83130,
#  'So we &apos;ve spent more time on focusing on why we should not talk to others than finding out how we talk to others .': 43538,
#  'Our demand for meat , dairy and refined carbohydrates -- the world consumes one billion cans or bottles of Coke a day -- our demand for these things , not our need , our want , drives us to consume way more calories than are good for us .': 8391,
#  'And there &apos;s some evidence that they are .': 98933,
#  'Now I &apos;m not saying for a minute that British Conservatives have all the answers .': 44874,
#  'And as it turns out , timing is also really , really important .': 31208,
#  'Now that title , that phrase , comes from a critic , an early critic , and this is a passage that I just love , and would like to read for you .': 61666,
#  'They were just there , but they had no significance .': 41702,
#  'I &apos;m sure you &apos;ve all seen or heard this before : &quot; We , the willing , have been doing so much with so little for so long -- -- we are now qualified to do anything with nothing . &quot;': 61940,
#  'In order to move up in organizations , you have to be known for your leadership skills , and this would apply to any of you , women or men .': 123300,
#  'I can only find cheese . I &apos;m sorry . So there it is .': 14711,
#  'This guy is stopping , dead stop , dead stop on the highway .': 98266,
#  'And that &apos;s led me to doing some work with the physical world , not with the Internet , and only using the Internet at the very last moment , as a presentation medium .': 106632,
#  'So it enables you to very rapidly aspirate , or suck out , rich bone marrow very quickly through one hole .': 26800,
#  'Another thing that helped me as a little kid is , boy , in the &apos; 50s , you were taught manners .': 38658,
#  'Something else you see that you talk about -- Americans don &apos;t talk about this , but you do .': 29321,
#  'And you can think about those as height , width and depth .': 17971,
#  'And then you go build on that in the next concept .': 101189,
#  'We &apos;re not doing that well when it comes to insurance .': 104155,
#  'By the way , what &apos;s going on with the eyes ?': 9414,
#  'A beefalo is a buffalo-cattle hybrid .': 4499,
#  'XL : Nah . Drugs are pretty messy . They spread everywhere .': 132926,
#  'Never before have expectations been so high about what human beings can achieve with their lifespan .': 56066,
#  'And so my principle has been to always present the shapes with different colorings because some colorings emphasize that , and others it is that or that .': 87090,
#  'And then , being an actor , I was doing these different kinds of things , and I felt the content of the work that I was involved in really wasn &apos;t cutting it , that there surely had to be more .': 7565,
#  'But when he got back home , he saw a miniature of the scaffolding six inches high , on his study table .': 6887,
#  'We need lots more .': 112801,
#  'If you knock them out completely , then you &apos;re very sick .': 100037,
#  'The problem of violence was stuck , and this has historically been the case in many other issues .': 93361,
#  'And third , so as people are doing this friends and family fundraising process , it &apos;s very awkward , people don &apos;t know exactly what to ask for , how to ask , what to promise in return , even though they have the best of intentions and want to thank those people that are supporting them .': 96429,
#  'You can see on the right here , there &apos;s a predator being chased away by the collective power of the birds , and apparently this is a frightening thing if you &apos;re a predator of starlings .': 43923,
#  'AO : -- who also was a pianist who couldn &apos;t see , and also , I think , like Derek , thought that all the world was a piano , so whenever Art Tatum plays something , it sounds like there &apos;s three pianos in the room .': 21311,
#  'So we can also eliminate the ugly ones or the caricatures .': 22960,
#  'Well it seems to me that we &apos;re now seeing a fundamental shift of power , broadly speaking , away from nations gathered around the Atlantic &#91; seaboard &#93; to the nations gathered around the Pacific rim .': 87668,
#  'I couldn &apos;t deal with the success of furniture -- I wasn &apos;t secure enough as an architect -- and so I closed it all up and made furniture that nobody would like .': 14004,
#  'It &apos;s exciting to see that in terms of what we &apos;ve learned , but how many of those 4,000 diseases now have treatments available ?': 52755,
#  'I couldn &apos;t prove it .': 19702,
#  'things die when there &apos;s no food .': 96062,
#  'They &apos;re all English and a little bit more sustainable .': 110700,
#  'And unlike traditional architecture , it &apos;s a single process that creates both the overall form and the microscopic surface detail .': 4025,
#  'And I asked her if she loved her baby .': 20212,
#  'And that is very useful information .': 49745,
#  'I mean , you have the typical European cities , with a dense urban core , good public transportation mostly , not a lot of road capacity .': 79165,
#  'What you just did , that &apos;s the first step towards taking responsibility for what we should do with all of our power .': 80857,
#  'And everywhere I lived , I learned the languages , but never mastered them .': 70585,
#  'It was about those lawn chairs .': 97197,
#  'Let me quickly give you three examples of startups that personally inspire me .': 120669,
#  'And I think philosophers need to rethink their philosophy for awhile .': 108882,
#  'In our country , there are groups of students who chronically underperform , for example , children in inner cities , or children on Native American reservations .': 121046,
#  'This subject constitutes just one chapter of my latest book , which compares traditional , small , tribal societies with our large , modern societies , with respect to many topics such as bringing up children , growing older , health , dealing with danger , settling disputes , religion and speaking more than one language .': 18290,
#  'So race , class , gender , ability , all of these things go into our experiences of what it means to be a woman .': 45136,
#  'Because although I &apos;ve used scientific terms in songs , it &apos;s very difficult sometimes to make them lyrical .': 103404,
#  'I think Stephen Covey had the right idea .': 70963,
#  'And I think that &apos;s one of the commonalities between modernism and traditional design . I think it may be a real common ground as we kind of figure out what on earth to do in the next 20 or 30 years .': 37193,
#  'Both black holes are getting closer together .': 16018,
#  'So when you say you feel remorse for your crime , they say , &apos; Typical of the psychopath to cunningly say he feels remorse when he doesn &apos;t . &apos; It &apos;s like witchcraft . They turn everything upside-down . &quot;': 76600,
#  'Now I &apos;ve been influenced in this thinking by two anecdotes that I want to share with you .': 114169,
#  'Two days it took the Times Online to make a map , a mashable map -- we call these things mash-ups -- a mashed-up user interface that allows you to go in there and have a look and find out whether your bicycle route to work was affected .': 112449,
#  'She said , &quot; Life &apos;s too short , I just can &apos;t keep going with this . &quot;': 61200,
#  'So we can bring the experiments of the 21st century by applying robotic technologies to this problem .': 107534,
#  'It just says &quot; Money , &quot; and if you look down the side street , it says , &quot; does not make me happy . &quot;': 78724,
#  'You will be able to look at all the aspects that make you yourself , all your experiences .': 95,
#  'We need to reinvent the whole model of scientific research .': 43863,
#  'Glenn Gray : Many veterans will admit that the experience of communal effort in battle has been the high point of their lives .': 99729,
#  'Peruvians love Japanese woodblock prints .': 14552,
#  'So , as all of you probably know , the classic way of thinking about this is the diffusion-of-innovation , or the adoption curve .': 69802,
#  'A recent study at Uppsala University in Sweden found that it &apos;s very difficult to frown when looking at someone who smiles .': 117583,
#  'This is another reason , I think , that parenthood feels like a crisis .': 128467,
# ...
#  'We &apos;ve had a mom in Utah who used them with her kids , to a science researcher in the U.K. , and curriculum developers in Hawaii .': 19482,
#  'So , children are not empty vessels , OK ?': 54134,
#  'But as we started asking ourselves about how we were addressing the higher needs of our employees and our customers , I realized we had no metrics .': 101370,
#  'So he was learning many different core principles of design , about how to experiment with new ideas , how to take complex ideas and break them down into simpler parts , how to collaborate with other people on your projects , about how to find and fix bugs when things go wrong , how to keep persistent and to persevere in the face of frustrations when things aren &apos;t working well .': 99589,
#  'I figure I &apos;m attracted to maybe one out of 10 of those men , and there was no way I was going to deal with somebody who was an avid golfer .': 31094,
#  'Okay , got it . I don &apos;t want to talk Stage One .': 6329,
#  'Romantic love is one of the most powerful sensations on Earth .': 73168,
#  'In the brewing process , there &apos;s lots of cloudy elements in the beer , so to get rid of these cloudy elements , what some companies do is they pour the beer through a sort of gelatin sieve in order to get rid of that cloudiness .': 81401,
#  'But in order to look at mobility and locomotion at this size scale to start , we &apos;re cheating and using magnets .': 120562,
#  'What is tenderness ?': 58917,
#  'And the second thing , which has stayed with me , which became my philosophy of life , which made all the difference , is : 100 things happen in your life , good or bad .': 36079,
#  'Sometimes it &apos;s hard to breathe , especially carrying all the heavy filming equipment .': 82236,
#  'The last thing I want to talk about today is the future of children &apos;s media .': 72562,
#  'Alright , so finally I &apos;m going to spend the rest of the talk , my last seven-and-a-half minutes , on step one ; namely , how do we actually get to this moderate amount of life extension that will allow us to get to escape velocity ?': 3074,
#  'I will not let silence wrap itself around my indecision .': 124820,
#  'Because there &apos;s a lot of money in sandalwoods .': 50309,
#  'And the thing would be to get up the databases free , to get them searchable , and with a second click , to get them into the graphic formats , where you can instantly understand them .': 87605,
#  'In other words , it &apos;s a matter of knowledge , not resources .': 31929,
#  'Stop . Look . Go .': 25780,
#  'It has the frequency of roughly 12 cycles per minute .': 43952,
#  'They really make Inside Out their own project .': 80057,
#  'It is displaying data that exists already in a different way , to amplify it , to provide cues to the doctors , to the nurses , so they can see what &apos;s happening .': 91469,
#  'And so every time a new medium arrives , the old medium is the content , and it is highly observable , highly noticeable , but the real , real roughing up and massaging is done by the new medium , and it is ignored .': 102227,
#  'To give you a better picture , think about a metropolitan area .': 37719,
#  'So I &apos;ve joined a growing band of people that try to make molecular spells using DNA . We use DNA because it &apos;s cheaper .': 81678,
#  'What we need in this space are strong data and analytics .': 71234,
#  'Here &apos;s the problem : Any serious candidate for our universe is inevitably full of computational irreducibility .': 49612,
#  'Now , have a look at that . That &apos;s the anesthesiology machine .': 61883,
#  'If you think about Adam Smith versus Karl Marx , Adam Smith had the very important notion of efficiency .': 2799,
#  'Solitude is where you find yourself so that you can reach out to other people and form real attachments .': 69465,
#  'Now is the time to believe .': 49112,
#  'They have to track the sun , because they have to be pointing directly at the sun .': 59555,
#  'Music I used to hear was bombs and fire of guns .': 115951,
#  'Well , ladies , at the beginning of our cycle , the hormone estrogen is dominant and that estrogen causes a suppression of your body temperature .': 125037,
#  'Every one of them becomes a louder and louder voice , but they don &apos;t represent us .': 73693,
#  'I &apos;m going to talk today about saving more , but not today , tomorrow .': 104128,
#  'And because the biggest producers of content on the Internet are not Google and Yahoo , they &apos;re us , we &apos;re the people getting policed .': 54009,
#  'We knew how brains see , and how they control the body and how they hear and sense .': 106331,
#  'When I tried my first trick , it looked like this .': 50233,
#  'It needs a means by which you can legitimize international action .': 87654,
#  'But what do we do for a living ?': 52977,
#  'And we don &apos;t have a huge number of people who got infected and never developed disease .': 108427,
#  'So here the nodes are companies , people , governments , foundations , etc .': 37696,
#  'Just completely independent entity , completely random occurrence , and the image , when I saw it , it really struck me .': 122283,
#  'And the United States is responsible for almost one half of the world &apos;s military spending -- four percent of the world &apos;s population .': 29323,
#  'And it was a prototype . And a month and a half later , I come back to Switzerland , and there he is playing with his own version .': 4452,
#  'Now , I also happen to be gay .': 61980,
#  'You don &apos;t know how you do it .': 15458,
#  'There is no longer any consistency in the surface signals .': 28328,
#  'In effect , they are the infidels .': 91372,
#  'In 1939 , the Radio Corporation of America introduced television .': 102158,
#  'We had a longer-term time perspective .': 118451,
#  'We &apos;ve got resources at the moment in 174 countries trying to get young people to be the driving force behind the vision of that global truce .': 7759,
#  'You have a large net in the middle with two steel doors on either end .': 77542,
#  'MM : Yeah , we &apos;re building a tool that makes it really easy for publishers right now to build this content .': 80354,
#  'And I also want to talk about what I call our new burden of knowledge .': 97875,
#  'Christien Meindertsma : How pig parts make the world turn': 81357,
#  'The very first PRISM slides from the beginning of June detail a collection program where the data is collected from service providers , and they actually go and name the service providers they have access to .': 10381,
#  'One guy who described himself as being lucky , because he lost his left arm , and he &apos;s a righty .': 68172,
#  'Why ? Because they have the data .': 109677,
#  'A group of males will grab a female , hold her down , and ballistically ejaculate their spiral-shaped penis into her corkscrew-shaped vagina over and over and over again .': 130178,
#  'So I think it &apos;s time for us to be comfortable with the uncomfortable conversation about race : black , white , Asian , Hispanic , male , female , all of us , if we truly believe in equal rights and equal opportunity in America , I think we have to have real conversations about this issue .': 127693,
#  'And they can afford to watch how we work -- like how security people work -- and try to work their way around any security precautions we can build .': 23433,
#  'Now I also said the other principle that I think we should work on is understanding of people , is recognizing that going with the grain of human nature you can achieve so much more .': 44930,
#  'And the tsunami of problems that we feel we &apos;re facing in terms of sustainability questions are actually a reflection of the exponential increase in urbanization across the planet .': 55694,
#  'I know my father isn &apos;t coming back , and that no one &apos;s prepared for the fire .': 20297,
#  'And suddenly she sees a tank ambling down the main road of Sarajevo knocking everything out of its path .': 78752,
#  'How do we survey populations that don &apos;t have access to technology , and speak languages we don &apos;t speak , and we don &apos;t know anyone who speaks those languages . Because in order to achieve on this great mission , we have to be able to do it .': 6394,
#  'And on your right you have a dependent public which is pathetically grateful for anything you give it .': 84554,
#  'Scientists have always created pictures as part of their thinking and discovery process .': 90030,
#  'Here is a pest , devastating pest , a spider mite , because it does a lot of webbing like a spider .': 60682,
#  'That &apos;s the major conclusion of the report on the economy and climate chaired by ex-President Felipe Calder\xc3\xb3n of Mexico , and I co-chaired that with him , and we handed that report yesterday here in New York , in the United Nations Building to the Secretary-General of the U.N. , Ban Ki-moon .': 123669,
#  'S : I don &apos;t want to let my parents down .': 30801,
#  'We got 50 in three days off Inishowen Peninsula .': 118075,
#  'This was the crossroad .': 105650,
#  'Steven Johnson : Where good ideas come from': 26409,
#  'This is an image I &apos;ve made out of lots and lots of Vicodin .': 35018,
#  'They keep it for -- you know , it &apos;s like the old wine bottles , you keep it for decoration or maybe fill it with water again , which proves it &apos;s not the water .': 20693,
#  'There &apos;s a song about India , and there &apos;s a description of the country as , it says , .': 130451,
#  'Now as seductive as the idea of control sounds , it &apos;s a false premise .': 1617,
#  'This is a tool -- this tells you I am in solidarity with people who have HIV , people who are living with HIV .': 48648,
#  'So , I &apos;m open to the possibilities of not knowing and finding out something new .': 15137,
#  'Which is my second favorite line in the entire oeuvre of Alfred Kinsey .': 81059,
#  'And one of them came to me the next morning and he said , &quot; You know , I &apos;ve never listened to classical music in my life , but when you played that shopping piece ... &quot; He said , &quot; My brother was shot last year and I didn &apos;t cry for him .': 67887,
#  'And it &apos;s been very exciting .': 777,
#  'And I understood that the building itself was a logo .': 105541,
#  'The average length of the forearm of a water polo player in relation to their total arm got longer , all the better for a forceful throwing whip .': 127893,
#  'Contrary to almost everything that you might get taught at an architecture school , copying is good .': 61444,
#  'I was just allowed to be me , growing and changing in every moment .': 24933,
#  'When I was 15 , and I called my father to tell him that I had fallen in love , it was the last thing on either of our minds to discuss what the consequences were of the fact that my first love was a girl .': 24930,
#  'How did the Chinese State Agency for Food and Drugs allow this to happen ? &quot;': 119025,
#  'And in one of his studies , what he did was he asked the British adolescents all sorts of questions , and then based on their answers , he said , &quot; I &apos;ve looked at your answers , and based on the answers , I have determined that you are either &quot; \xe2\x80\x94 he told half of them \xe2\x80\x94 &quot; a Kandinsky lover , you love the work of Kandinsky , or a Klee lover , you love the work of Klee . &quot;': 125585,
#  'And if I tried , I &apos;d disappoint them .': 114194,
#  'So , chemistry is dominated by the electromagnetic force .': 78611,
#  'And it &apos;s this importance why I decided to look into the issues that this technology has , because it &apos;s so fundamental to our lives .': 26631,
#  'The Wayne County Child Welfare Protection Agency said no .': 42537,
#  'The Internet is a fantastic resource for business , for political expression , for art and for learning .': 63118,
#  'These freckles are called sunspots , and they are just one of the manifestations of the Sun &apos;s magnetic field .': 46913,
#  '&#91; Every classroom could look like that &#93; Bill Gates : One day , we &apos;d like every classroom in America to look something like that .': 38001,
#  'The acoustician in the competition gave us criteria , which led to this compartmentalized scheme , which we found out after the competition would not work at all .': 14326,
#  'So why does good sex so often fade ?': 3771,
#  'That thin sliver you see here , that &apos;s Africa .': 12650,
#  'So we cut into them .': 41448,
#  'And some people think that &apos;s a good thing .': 69381,
#  'And it &apos;s just incrementally , over the last 20 years , built urbanism on top of its parking lots .': 12512,
#  'We are anxious that we are not good enough .': 63801,
#  'They were change agents , and they left for me a legacy .': 125533,
#  'I &apos;m going to talk about dinosaurs .': 41280,
#  'And to imagine is to put myself in that story , until there was only -- there is a transparency between me and the story that I am creating .': 7292,
#  'It is not about documentation and contract .': 63635,
#  'Do they even take the very waste matter that we have from food and fiber and so forth , and turn it back into soil and sequester carbon -- take carbon out of the air in the process of using our cities ?': 19907,
#  'And so if you change the recipe , and you add things when you pour -- so you add things to your liquid silk solution -- where these things are enzymes or antibodies or vaccines , the self-assembly process preserves the biological function of these dopants .': 17163,
#  'And then the third one is this idea of the end of oil , this entropic end , where all of our parts of cars , our tires , oil filters , helicopters , planes -- where are the landscapes where all of that stuff ends up ?': 95280,
#  'And I &apos;ve got to think of my youngsters at UCLA -- 30-some attorneys , 11 dentists and doctors , many , many teachers and other professions .': 91966,
#  'Of course , camera angle is everything . The photographer is over there , and this board appears to overlap with this one , and this one with that one , and so on .': 119552,
#  'So we &apos;re thinking , we could throw up a bunch of satellites and use it to track our submarines and figure out their location in the middle of the ocean .': 26557,
#  'Proofing means to prove that the dough is alive .': 115489,
#  'There was an enormous gap in the world when I grew up .': 8927,
#  'What &apos;s the context of this meal ?': 93789,
#  'But of course , we do have young people who would still prefer to smile , whether in a BMW or &#91; on &#93; a bicycle .': 105417,
#  'And what we &apos;ve been working out is the implications , really , of the idea that the universe is made up of relations .': 66880,
#  'And I &apos;m not sure that was real interaction .': 2009,
#  'What they had was dopa-responsive dystonia .': 57998,
#  'With the same method , we can also get him to circle a person .': 4671,
#  'But I just started again an hour ago . &quot;': 26909,
#  'AM : Yes . These I got in a place called Bournemouth , England , about two hours south of London , and I &apos;m the only person in the United States with these , which is a crime because they are so beautiful .': 83357,
#  'Given this rich artistic environment , you &apos;d assume that I would have been compelled to go into the family business , but no .': 129744,
#  'We do that corporate -- whether it &apos;s a bailout , an oil spill , a recall -- we pretend like what we &apos;re doing doesn &apos;t have a huge impact on other people .': 90931,
#  'This internal sense of rightness that we all experience so often is not a reliable guide to what is actually going on in the external world .': 5836,
#  'Perhaps overlooked , Volta &apos;s invention of the battery for the first time also demonstrated the utility of a professor .': 51809,
#  'And here she relates , in the documentary film &quot; Afghan Star , &quot; how her friends urged her not to do this and told her that she was leaving them for democracy .': 32002,
#  'And then finally , DVDs are approaching free .': 79816,
#  ...}

# %%
from seq2seq import Seq2SeqModel
sqmod = Seq2SeqModel()
# Out:
#   File "seq2seq.py", line 271
#     self.outputs[b] = (tf.matmul(x, projection[0] + projection[1] for x in self.outputs[b]))
# SyntaxError: Generator expression must be parenthesized if not sole argument
